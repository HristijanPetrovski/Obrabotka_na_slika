# %%
import os
import cv2
import numpy as np
from matplotlib import pyplot as plt

path = '\\database\\'

path_processed = '\\repos\\Examples\\Domasna 3\\database_segment\\'

folder = os.fsencode(path)

filenames = []

for file in os.listdir(folder):
    file = file.decode("utf-8")
    if not file.endswith(".jpg"):
        continue
#     print(file)
    img = cv2.imread(path+file,0)
#     print(img)
    segment1(img,path+file)
# Out:
# \database\1.jpg
# \database\10000.jpg
# \database\10001.jpg
# \database\10002.jpg
# \database\10005.jpg
# \database\10152.jpg
# \database\10309.jpg
# \database\10368.jpg
# \database\10379.jpg
# \database\10414.jpg
# \database\10456.jpg
# \database\10479.jpg
# \database\10492.jpg
# \database\10677.jpg
# \database\10752.jpg
# \database\10828.jpg
# \database\10939.jpg
# \database\11150.jpg
# \database\11187.jpg
# \database\11190.jpg
# \database\11248.jpg
# \database\11250.jpg
# \database\11269.jpg
# \database\11270.jpg
# \database\11361.jpg
# \database\11606.jpg
# \database\11628.jpg
# \database\11721.jpg
# \database\13567.jpg
# \database\1402.jpg

# %%
def segment1(img, name):    
    img = cv2.medianBlur(img,5)
    ret,th1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
    th2 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY,11,2)
    th3 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY,11,2)

    titles = ['Original Image', 'Global Thresholding (v = 127)','Adaptive Mean Thresholding', 'Adaptive Gaussian Thresholding']
    images = [img, th1, th2, th3]

    for i in range(4):
        plt.subplot(2,2,i+1),plt.imshow(images[i],'gray')
        plt.title(titles[i])
        plt.xticks([]),plt.yticks([])
    print(name)
    plt.savefig(name, dpi=100)
    plt.show()
